# %%
import os
import sys
import django
from django.db import connection
from tqdm import tqdm
import logging
import pandas as pd
from datetime import datetime
import re

# %%
sys.path.insert(0, "/Users/victornguyen/Sites/07.book_management")
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "book_management.settings")
django.setup()
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.DEBUG)
logger = logging.getLogger('User similarity calculator')

# Import Models
from title.models import Title
from main_site.models import BookSimilarity

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# %%
features = ['author', 'author', 'faculty', 'faculty', 'publisher']

# %%
def clean_data(x):
    if isinstance(x, str):
        x = str.lower(x.replace(" ", ""))
        x = x.replace("unknown", " ")
        return x.replace(",", " ")
    else:
        return ''

# %%
def create_bag_of_words(x):
    name_temp = re.sub(r"[^a-zA-Z]+", ' ', x['name'])
    name_temp = name_temp.replace(" st","")
    name_temp = name_temp.replace(" nd","")
    name_temp = name_temp.replace(" rd","")
    name_temp = name_temp.replace(" th","")
    name_temp = name_temp.replace(" ed","")
    temp = ''
    temp += str.lower(name_temp)
    temp += str.lower(name_temp)
    temp += str.lower(name_temp)
    for feature in features:
        temp += x[feature + '_clean'] + ' '
    return temp

# %%
def load_data():
    db_book_list = Title.objects.all().order_by('id')
    db_book_list = [Title.book_info_as_dict(book) for book in db_book_list]
    db_book_list = pd.DataFrame.from_dict(db_book_list, orient='columns')
    db_book_list['type'] = 'database'
    return db_book_list

# %%
logger.info("Calculate item similarity")
logger.info("Load all item")
book_list_df = load_data()
book_list_df.head()
# Out:
# 2019-07-19 02:12:22,420 : INFO : Calculate item similarity
# 2019-07-19 02:12:22,422 : INFO : Load all item
#                              author faculty  id  isbn location  \
# 0      Project management Institute     ISE   1  None     None
# 1     Igor A. Karnovsky, Olga Lebed      CE   2  None     None
# 2                    Alan L. Harvey      BT   3  None     None
# 3                   Frank K. Reilly  BA, FN   4  None     None
# 4  John S. Lucas, Paul C. Southgate      BT   5  None     None
#
#                                                 name  \
# 0  A guide to the project management body of know...
# 1            Advanced Methods of Structural Analysis
# 2              Advances in Drug Discovery Techniques
# 3  Analysis of investment & management of portfol...
# 4  Aquaculture: Farming Aquatic Animals and Plant...
#
#                             publisher  year      type
# 0  Project Management Institute, Inc.  2008  database
# 1                            Springer  2010  database
# 2                   John Wiley & Sons  1998  database
# 3      South-Western Cengage Learning  2012  database
# 4                   John Wiley & Sons  2011  database

# %%
logger.info("Save rating into database")
logger.info("Clean data")
# Apply clean_data function to your features.
for feature in features:
    book_list_df[feature + '_clean'] = book_list_df[feature].apply(clean_data)
book_list_df.head()
# Out:
# 2019-07-19 02:12:24,176 : INFO : Save rating into database
# 2019-07-19 02:12:24,180 : INFO : Clean data
#                              author faculty  id  isbn location  \
# 0      Project management Institute     ISE   1  None     None
# 1     Igor A. Karnovsky, Olga Lebed      CE   2  None     None
# 2                    Alan L. Harvey      BT   3  None     None
# 3                   Frank K. Reilly  BA, FN   4  None     None
# 4  John S. Lucas, Paul C. Southgate      BT   5  None     None
#
#                                                 name  \
# 0  A guide to the project management body of know...
# 1            Advanced Methods of Structural Analysis
# 2              Advances in Drug Discovery Techniques
# 3  Analysis of investment & management of portfol...
# 4  Aquaculture: Farming Aquatic Animals and Plant...
#
#                             publisher  year      type  \
# 0  Project Management Institute, Inc.  2008  database
# 1                            Springer  2010  database
# 2                   John Wiley & Sons  1998  database
# 3      South-Western Cengage Learning  2012  database
# 4                   John Wiley & Sons  2011  database
#
#                   author_clean faculty_clean                  publisher_clean
# 0   projectmanagementinstitute           ise  projectmanagementinstitute inc.
# 1    igora.karnovsky olgalebed            ce                         springer
# 2                 alanl.harvey            bt                   johnwiley&sons
# 3                frankk.reilly         ba fn     south-westerncengagelearning
# 4  johns.lucas paulc.southgate            bt                   johnwiley&sons

# %%
# Create meta bag of words
book_list_df['bag_of_words'] = book_list_df.apply(create_bag_of_words, axis=1)
for index, row in book_list_df.iterrows():
    print(row['bag_of_words'],'\n')
book_list_df.head()
# Out:
# a guide toe project management body of knowledge a guide toe project management body of knowledge a guide toe project management body of knowledge projectmanagementinstitute projectmanagementinstitute ise ise projectmanagementinstitute inc.
#
# advanced methods of structural analysisadvanced methods of structural analysisadvanced methods of structural analysisigora.karnovsky olgalebed igora.karnovsky olgalebed ce ce springer
#
# advances in drug discovery techniquesadvances in drug discovery techniquesadvances in drug discovery techniquesalanl.harvey alanl.harvey bt bt johnwiley&sons
#
# analysis of investment management of portfolios analysis of investment management of portfolios analysis of investment management of portfolios frankk.reilly frankk.reilly ba fn ba fn south-westerncengagelearning
#
# aquaculture farming aquatic animals and plants aquaculture farming aquatic animals and plants aquaculture farming aquatic animals and plants johns.lucas paulc.southgate johns.lucas paulc.southgate bt bt johnwiley&sons
#
# architecture form space and order architecture form space and order architecture form space and order francisd.k.ching francisd.k.ching ce ce johnwiley&sons
#
# auditing and assurance services a systematic approach auditing and assurance services a systematic approach auditing and assurance services a systematic approach douglasf.prawitt stevenm.glover williamf.messier douglasf.prawitt stevenm.glover williamf.messier ba fn ba fn mcgrawhill
#
# bioinformatics for high throughput sequencingbioinformatics for high throughput sequencingbioinformatics for high throughput sequencinganam.aransay michaelhackenberg naiararodríguez-ezpeleta anam.aransay michaelhackenberg naiararodríguez-ezpeleta bt bt springer
#
# biosignal and biomedical image processing biosignal and biomedical image processing biosignal and biomedical image processing johnl.semmlow johnl.semmlow bme bme crcpress
#
# building an import export business building an import export business building an import export business kennethd.weiss kennethd.weiss ba ba wiley&​sons
#
# business analysis and valuation using financial statements text and cases business analysis and valuation using financial statements text and cases business analysis and valuation using financial statements text and cases aswathdamodaran krishnag.palepu aswathdamodaran krishnag.palepu ba ba south-westerncengagelearning
#
# business ethics a real world approachbusiness ethics a real world approachbusiness ethics a real world approachandrewghillyer andrewghillyer ba ba mcgrawhill
#
# business market management understanding creating and delivering value piebusiness market management understanding creating and delivering value piebusiness market management understanding creating and delivering value piedasnarayandas jamesc.anderson dasnarayandas jamesc.anderson ba ba pearsoneducationlimited
#
# business research methods business research methods business research methods donaldr.cooper pamelas.schindler donaldr.cooper pamelas.schindler ba ba singapore
#
# cell biology cell biology cell biology geraldkarp geraldkarp bt bt newyork
#
# chemistry for engineers an applied approachchemistry for engineers an applied approachchemistry for engineers an applied approachmaryjaneshultz maryjaneshultz bt bt houghtonmifflin
#
# commercial banking the management of risk commercial banking the management of risk commercial banking the management of risk bentone.gup jamesw.kolari bentone.gup jamesw.kolari ba ba wiley
#
# computer networking a top down approach computer networking a top down approach computer networking a top down approach jamesf.kurose keithw.ross jamesf.kurose keithw.ross ee ee pearsoneducation inc.
#
# computer organization and design computer organization and design computer organization and design davida.patterson johnl.hennessy davida.patterson johnl.hennessy ee ee elsevier
#
# consumer behavior buying having and being edition pieconsumer behavior buying having and being edition pieconsumer behavior buying having and being edition piemichaelr.solomon michaelr.solomon ba ba pearsoneducationlimited
#
# corporate finance asia adaptation ecorporate finance asia adaptation ecorporate finance asia adaptation erandolphwesterfield stephena.ross randolphwesterfield stephena.ross ba fn ba fn mcgrawhill
#
# credit analysis and lending managementcredit analysis and lending managementcredit analysis and lending managementjamesbartle milindsathye raymondboffey jamesbartle milindsathye raymondboffey ba fn ba fn victildepublishinganddistribution
#
# critical thinking a student s introduction critical thinking a student s introduction critical thinking a student s introduction gregorybassham henrynardone jameswallace williamirwin gregorybassham henrynardone jameswallace williamirwin ise ise prenticehall
#
# data communications and networking data communications and networking data communications and networking behrouza.forouzan behrouza.forouzan ee ee mcgrawhill
#
# database system concepts database system concepts database system concepts abrahamsilberschatz henryf.korth s.sudarshan abrahamsilberschatz henryf.korth s.sudarshan ise ise mcgrawhill
#
# design and analysis of experiments design and analysis of experiments design and analysis of experiments douglasc.montgomery douglasc.montgomery ise ise illinoiswavelandpress
#
# digital marketing strategy implementation and practice digital marketing strategy implementation and practice digital marketing strategy implementation and practice davechaffey fionaellis-chadwick kevinjohnston richardmayer davechaffey fionaellis-chadwick kevinjohnston richardmayer ba ba pearson
#
# discrete event system simulation discrete event system simulation discrete event system simulation barryl.nelson davidm.nicol jerrybanks johnscarson barryl.nelson davidm.nicol jerrybanks johnscarson ise ise prenticehall
#
# dynamics of structures theory and applications to earthquake engineering dynamics of structures theory and applications to earthquake engineering dynamics of structures theory and applications to earthquake engineering anilk.chopra anilk.chopra ce ce pearson
#
# electric circuits electric circuits electric circuits jamesw.nilsson susanriedel jamesw.nilsson susanriedel ee ee prenticehall
#
# elements of engineering electromagnetics elements of engineering electromagnetics elements of engineering electromagnetics nannapaneninarayanarao nannapaneninarayanarao ee ee prenticehall
#
# e logistics and e supply chain management applications for evolving businesse logistics and e supply chain management applications for evolving businesse logistics and e supply chain management applications for evolving businessderyngraham dimitrisfolinas ioannismanikas deryngraham dimitrisfolinas ioannismanikas ise ise prenticehall
#
# engineering drawingengineering drawingengineering drawingagrawalbasant agrawalbasant ise ise newdelhi
#
# engineering economy engineering economy engineering economy c.p.koelling e.m.wicks w.g.sullivan c.p.koelling e.m.wicks w.g.sullivan ise ise pearson
#
# engineering mechanics vol statics engineering mechanics vol statics engineering mechanics vol statics j.l.meriam l.g.kraige j.l.meriam l.g.kraige ce ce johnwiley&sons
#
# entrepreneurship and small firms entrepreneurship and small firms entrepreneurship and small firms daviddeakins markfreel daviddeakins markfreel ise ise london
#
# essentials of services marketing essentials of services marketing essentials of services marketing christopherlovelock jochenwirtz patriciachew christopherlovelock jochenwirtz patriciachew ba ba pearsoneducationsouthasiapteltd.
#
# facilities planningitionfacilities planningitionfacilities planningitionj.m.a.tanchoco jamea.tompkins johna.white yavuza.bozer j.m.a.tanchoco jamea.tompkins johna.white yavuza.bozer ise ise wiley
#
# factory physics factory physics factory physics markl.spearman wallacej.hopp markl.spearman wallacej.hopp ise ise wavelandpress
#
# financial accouting financial accouting financial accouting janwilliams josephcarcello markbettner suehaka janwilliams josephcarcello markbettner suehaka ba ba mcgrawhill
#
# financial institutions management a risk management approach financial institutions management a risk management approach financial institutions management a risk management approach anthonysaunders marciamilloncornett anthonysaunders marciamilloncornett ba fn ba fn mcgrawhill
#
# financial markets and institutionsfinancial markets and institutionsfinancial markets and institutionsfrederickmishkin stanleyeakins frederickmishkin stanleyeakins ba ba boston
#
# financial reporting and analysis financial reporting and analysis financial reporting and analysis collins revsine collins revsine ba fn ba fn mcgrawhill
#
# fish disease diagnosis and treatment fish disease diagnosis and treatment fish disease diagnosis and treatment edwardj.noga edwardj.noga bt bt wiley-blackwell
#
# food analysis food analysis food analysis s.suzannenielsen s.suzannenielsen bt bt springer
#
# food microbiology a laboratory manualfood microbiology a laboratory manualfood microbiology a laboratory manualahmede.yousef ahmedyousef carolyncarlstrom ahmede.yousef ahmedyousef carolyncarlstrom bt bt wiley
#
# food packaging principles and practice food packaging principles and practice food packaging principles and practice gordonl.robertson gordonl.robertson bt bt taylor&francis
#
# food product developmentfood product developmentfood product developmentallanm.anderson maryearle richardl.earle allanm.anderson maryearle richardl.earle bt bt crcpress
#
# fundamentals of human resource management fundamentals of human resource management fundamentals of human resource management barrygerhart johnr.hollenbeck patrickm.wright raymonda.noe barrygerhart johnr.hollenbeck patrickm.wright raymonda.noe ba ba mcgrawhill
#
# fundamentals of corporate finance fundamentals of corporate finance fundamentals of corporate finance brealey marcus myers brealey marcus myers ba fn ba fn mcgrawhill
#
# fundamentals of molecular diagnosticsfundamentals of molecular diagnosticsfundamentals of molecular diagnosticscarla.burtisphd davide.bruns edwardr.ashwood carla.burtisphd davide.bruns edwardr.ashwood bt bt elsevier
#
# gene cloning and dna analysis an introduction gene cloning and dna analysis an introduction gene cloning and dna analysis an introduction t.a.brown t.a.brown bt bt wiley
#
# integrated circuit design integrated circuit design integrated circuit design davidmoneyharris neilh.e.weste davidmoneyharris neilh.e.weste ee ee pearson
#
# international business an asian perpectiveinternational business an asian perpectiveinternational business an asian perpectivecharlesw.lhill chow-houwee krishnaudayasankar charlesw.lhill chow-houwee krishnaudayasankar ba ba mcgrawhill
#
# international corporate finance international corporate finance international corporate finance jeffmadura jeffmadura ba ba south-westerncengagelearning
#
# introduction to derivatives and risk management with ebookintroduction to derivatives and risk management with ebookintroduction to derivatives and risk management with ebookdonm.chance robertbrooks donm.chance robertbrooks ba fn ba fn cengagelearning
#
# introduction to entrepreneurship introduction to entrepreneurship introduction to entrepreneurship donaldf.kuratko donaldf.kuratko ba ba south-westerncengagelearning
#
# introduction to food engineering introduction to food engineering introduction to food engineering dennisr.heldman r.paulsingh dennisr.heldman r.paulsingh bt bt academicpress
#
# introduction to hydrology introduction to hydrology introduction to hydrology garyl.lewis warrenviessman garyl.lewis warrenviessman ce ce pearsoneducation inc.
#
# introduction to limnology introduction to limnology introduction to limnology stanleydodson stanleydodson bt bt mcgrawhill
#
# introduction to matlab for engineers introduction to matlab for engineers introduction to matlab for engineers williamj.palm williamj.palm ise ise mcgrawhill
#
# introduction to operations research introduction to operations research introduction to operations research hiller lieberman hiller lieberman ise ise mcgrawhill
#
# introduction to probability and statistics for engineers and scientist introduction to probability and statistics for engineers and scientist introduction to probability and statistics for engineers and scientist sheldonm.ross sheldonm.ross ise ise amsterdam boston
#
# introduction to probability modelsintroduction to probability modelsintroduction to probability modelssheldonm.ross sheldonm.ross ise ise academicpress
#
# introduction to probability models operations research volume introduction to probability models operations research volume introduction to probability models operations research volume waynel.winston waynel.winston ise ise australia
#
# introduction to psychology introduction to psychology introduction to psychology haigkouyoumdjian rodplotnik haigkouyoumdjian rodplotnik ba ba cengagelearning
#
# introduction to time series analysis and forecastingintroduction to time series analysis and forecastingintroduction to time series analysis and forecastingcheryll.jennings douglasc.montgomery muratkulahci cheryll.jennings douglasc.montgomery muratkulahci ise ise newjersey
#
# investment banking valuation leveraged buyouts and mergers acquisitions investment banking valuation leveraged buyouts and mergers acquisitions investment banking valuation leveraged buyouts and mergers acquisitions joshuapearl joshuarosenbaum joshuapearl joshuarosenbaum ba fn ba fn johnwiley&sons
#
# java how to program java how to program java how to program paulj.deitel paulj.deitel it it prenticehall
#
# leadership theory and practice leadership theory and practice leadership theory and practice peterg.northouse peterg.northouse ise ise sages
#
# linear systems and signals linear systems and signals linear systems and signals b.p.lathi b.p.lathi ee ee oxforduniversitypress
#
# managemente new workplace managemente new workplace managemente new workplace dorothymarcic richardl.daft dorothymarcic richardl.daft ba ba south-westerncengagelearning
#
# managerial accouting tools for decision making managerial accouting tools for decision making managerial accouting tools for decision making donalde.kieso jerryj.weygandt pauld.kimmel donalde.kieso jerryj.weygandt pauld.kimmel ba ba wiley
#
# managerial economics economic tools for today s decision maker managerial economics economic tools for today s decision maker managerial economics economic tools for today s decision maker paulg.keat philipk.y.young paulg.keat philipk.y.young ba ba pearson
#
# managing human resources human resource management in transition managing human resources human resource management in transition managing human resources human resource management in transition martinr.edwards stephenbach martinr.edwards stephenbach ba ba newjersey
#
# materials for civil and construction engineers materials for civil and construction engineers materials for civil and construction engineers johnp.zaniewski michaels.mamlouk johnp.zaniewski michaels.mamlouk ce ce pearson
#
# materials handling principles and practicematerials handling principles and practicematerials handling principles and practicetheodoreh.allegri theodoreh.allegri ise ise florida
#
# medical instrumentation application and design medical instrumentation application and design medical instrumentation application and design jong.webster jong.webster bme bme wiley
#
# medical microbiologymedical microbiologymedical microbiologyf.kayser j.eckert k.bienz r.zinkernagel f.kayser j.eckert k.bienz r.zinkernagel bt bt thieme
#
# microelectronic circuits microelectronic circuits microelectronic circuits adels.sedra kennethc.smith adels.sedra kennethc.smith ee ee oxforduniversitypress
#
# modern food microbiology modern food microbiology modern food microbiology davida.golden jamesm.jay martinj.loessner davida.golden jamesm.jay martinj.loessner bt bt springer
#
# multinational business financemultinational business financemultinational business financearthuri.stonehill ​davidk.eiteman michaelh.moffett arthuri.stonehill ​davidk.eiteman michaelh.moffett ba fn ba fn boston
#
# networks and discrete location models algorithms and applications networks and discrete location models algorithms and applications networks and discrete location models algorithms and applications marks.daskin marks.daskin ise ise newjersey
#
# new product management new product management new product management c.anthonydibenedetto c.merlecrawford c.anthonydibenedetto c.merlecrawford ba ba mcgrawhill
#
# next generation sequencing and whole genome selection in aquaculturenext generation sequencing and whole genome selection in aquaculturenext generation sequencing and whole genome selection in aquaculturezhanjiang(john)liu zhanjiang(john)liu bt bt wiley
#
# nutrition and feeding of fish and crustaceansnutrition and feeding of fish and crustaceansnutrition and feeding of fish and crustaceansj.watson jeanguillaume pierrebergot robertmetailler sadasivamkaushik j.watson jeanguillaume pierrebergot robertmetailler sadasivamkaushik bt bt springer
#
# operating systems internals and design principles operating systems internals and design principles operating systems internals and design principles williamstallings williamstallings it it pearson
#
# operations management e pieoperations management e pieoperations management e piebarryrender jayheizer barryrender jayheizer ba ba pearsoneducationlimited
#
# operations research applications and algorithms operations research applications and algorithms operations research applications and algorithms waynel.winston waynel.winston ise ise australia
#
# optimization in operations research pearson new international optimization in operations research pearson new international optimization in operations research pearson new international ronaldl.rardin ronaldl.rardin ise ise pearson
#
# organic chemistry organic chemistry organic chemistry leroyg.wade leroyg.wade bt bt prenticehall
#
# pharmaceutical biotechnology concepts and applicationspharmaceutical biotechnology concepts and applicationspharmaceutical biotechnology concepts and applicationsgarywalsh garywalsh bt bt wiley
#
# pharmaceutical biotechnology drug discovery and clinical applicationspharmaceutical biotechnology drug discovery and clinical applicationspharmaceutical biotechnology drug discovery and clinical applicationsoliverkayser rainerh.miller oliverkayser rainerh.miller bt bt wiley
#
# pic microcontroller and embedded systems using assembly and c for pic pic microcontroller and embedded systems using assembly and c for pic pic microcontroller and embedded systems using assembly and c for pic muhammadalimazidi rolind.mckinlay muhammadalimazidi rolind.mckinlay ee ee prenticehall
#
# planning and scheduling in manufacturing and services planning and scheduling in manufacturing and services planning and scheduling in manufacturing and services michaell.pineido michaell.pineido ise ise springer
#
# principles of banking principles of banking principles of banking   ba fn ba fn americanbankersassociation
#
# principles of economics principles of economics principles of economics n.gregorymankiw n.gregorymankiw ba ba south-westerncengagelearning
#
# principles of foundation engineering principles of foundation engineering principles of foundation engineering brajam.das brajam.das ce ce cengagelearning
#
# principles of geotechnical engineering principles of geotechnical engineering principles of geotechnical engineering brajam.das brajam.das ce ce cengagelearning
#
# principles of marketing pieprinciples of marketing pieprinciples of marketing piegaryarmstrong philipkotler garyarmstrong philipkotler ba ba pearsoneducationlimited
#
# principles of physics principles of physics principles of physics davidhalliday jearlwalker robertresnick davidhalliday jearlwalker robertresnick ph ph wiley
#
# principles of risk management and insurance principles of risk management and insurance principles of risk management and insurance georgee.rejda georgee.rejda ba ba pearson
#
# principles of taxation for business and investment planning editionprinciples of taxation for business and investment planning editionprinciples of taxation for business and investment planning editionsallym.jones shelleyc.rhoades-catanach sallym.jones shelleyc.rhoades-catanach ba fn ba fn mcgrawhill
#
# product design and development product design and development product design and development karlulrich steveneppinger karlulrich steveneppinger ise ise mcgrawhill
#
# production and operations analysis strategy quality analytics application production and operations analysis strategy quality analytics application production and operations analysis strategy quality analytics application stevennahmias tavalennonolsen stevennahmias tavalennonolsen ise ise illinoiswavelandpress
#
# project management a managerial approach project management a managerial approach project management a managerial approach jackr.meredith samuelj.mantel jackr.meredith samuelj.mantel ba ba wiley
#
# project management processes methodologies and economics project management processes methodologies and economics project management processes methodologies and economics avrahamshtub jonathanf.bard shlomogloberson avrahamshtub jonathanf.bard shlomogloberson ba ba prenticehall
#
# project management the managerial process project management the managerial process project management the managerial process cliffordgray eriklarson cliffordgray eriklarson ba ba mcgrawhill
#
# protein engineering for industrial biotechnologyprotein engineering for industrial biotechnologyprotein engineering for industrial biotechnologyliliaalberghina liliaalberghina bt bt harwoodacademicpublishers
#
# quantitative analysis for management quantitative analysis for management quantitative analysis for management barryrender michaele.hanna ralphm.stair barryrender michaele.hanna ralphm.stair ba ba pearson
#
# reinforced concrete design to eurocode reinforced concrete design to eurocode reinforced concrete design to eurocode billmosley billmosley ce ce palgrave
#
# retailing management retailing management retailing management bartona.weitz dhruvgrewal michaellevy bartona.weitz dhruvgrewal michaellevy ise ise mcgrawhill
#
# sales management concepts and cases sales management concepts and cases sales management concepts and cases thomase.decarlo williaml.cron thomase.decarlo williaml.cron ba ba wiley
#
# schedulingeory algorithms and systems schedulingeory algorithms and systems schedulingeory algorithms and systems michaell.pinedo michaell.pinedo ise ise newyork
#
# simulation modeling and analysis simulation modeling and analysis simulation modeling and analysis averillm.law averillm.law ise ise mcgrawhill
#
# sociology a brief introduction sociology a brief introduction sociology a brief introduction richardt.schaefer richardt.schaefer ba ba mcgrawhill
#
# software engineering software engineering software engineering iansommerville iansommerville it it pearson
#
# statics and mechanics of materials statics and mechanics of materials statics and mechanics of materials r.c.hibbeler s.c.fan r.c.hibbeler s.c.fan ce ce prenticehall
#
# strategic brand management strategic brand management strategic brand management kevinlanekeller kevinlanekeller ba ba pearson
#
# supply chain management an introduction to logistics supply chain management an introduction to logistics supply chain management an introduction to logistics donaldwaters donaldwaters ise ise palgrave
#
# supply chain management strategy planning and operation supply chain management strategy planning and operation supply chain management strategy planning and operation petermeindl sunilchopra petermeindl sunilchopra ise ise pearson
#
# supply chain risk management ulnerability and resilience in logistics supply chain risk management ulnerability and resilience in logistics supply chain risk management ulnerability and resilience in logistics donaldwaters donaldwaters ise ise london
#
# supply chainructures coordination information and optimizationsupply chainructures coordination information and optimizationsupply chainructures coordination information and optimizationdavidd.yao jing-shengsong davidd.yao jing-shengsong ise ise boston
#
# sustainable logistics and supply chain management principles and practices for sustainable operations and managementsustainable logistics and supply chain management principles and practices for sustainable operations and managementsustainable logistics and supply chain management principles and practices for sustainable operations and managementalexandertrautims cheeyewwong davidb.grant alexandertrautims cheeyewwong davidb.grant ise ise london
#
# systems analysis and design systems analysis and design systems analysis and design kendall kendall ise ise pearson
#
# the behaviour and design ofeelructures to ec the behaviour and design ofeelructures to ec the behaviour and design ofeelructures to ec bradfurdm.a. tranairn.s. bradfurdm.a. tranairn.s. ce ce taylor&francis
#
# the physiology of fishes the physiology of fishes the physiology of fishes davidh.evans jamesb.claiborne davidh.evans jamesb.claiborne bt bt crcpress
#
# tools of radio astronomy tools of radio astronomy tools of radio astronomy kristenrohlfs susannehuettemeister thomasl.wilson kristenrohlfs susannehuettemeister thomasl.wilson ph ph newyork
#
# toyota production system an integrated approach to just in time editiontoyota production system an integrated approach to just in time editiontoyota production system an integrated approach to just in time editionyasuhiromonden yasuhiromonden ise ise crcpress
#
# understanding business understanding business understanding business williamg.nickels williamg.nickels ba ba mcgrawhill
#
# warehousing ine global supply chainwarehousing ine global supply chainwarehousing ine global supply chainriccardomanzini riccardomanzini ise ise springer
#
# wastewater engineering treatment and reuse wastewater engineering treatment and reuse wastewater engineering treatment and reuse franklinlburton georgetchobanoglous franklinlburton georgetchobanoglous bt bt mcgrawhill
#
# water supply and sewerage water supply and sewerage water supply and sewerage terencej.mcghee terencej.mcghee ce ce mcgrawhill
#
# work systems the methods measurement management of work piework systems the methods measurement management of work piework systems the methods measurement management of work piemikellp.groover mikellp.groover ise ise pearsonprenticehall
#
# working capital management applications and casesworking capital management applications and casesworking capital management applications and casesjamess.sagner jamess.sagner ba ba johnwiley&sons
#
# corporate governance principles policies and practices corporate governance principles policies and practices corporate governance principles policies and practices bobtricker bobtricker ba ba oxforduniversitypress
#
# e commerce business technology society e commerce business technology society e commerce business technology society carolguerciotraver kennethc.laudon carolguerciotraver kennethc.laudon ba ba pearson
#
# environmental economics an introduction environmental economics an introduction environmental economics an introduction barryc.field marthak.field barryc.field marthak.field ba ba mcgrawhill
#
# international human resource management international human resource management international human resource management allend.engle marionfesting peterj.dowling allend.engle marionfesting peterj.dowling ba ba cengagelearning
#
# marketingrategy a decision focused approach marketingrategy a decision focused approach marketingrategy a decision focused approach johnw.mullins orvillec.walker johnw.mullins orvillec.walker ba ba mcgrawhill
#
# natural resource and environmental economicsnatural resource and environmental economicsnatural resource and environmental economicsdavidmaddison jamesmcgilvray michaelcommon rogerperman yuema davidmaddison jamesmcgilvray michaelcommon rogerperman yuema ba ba pearsonaddisonwesley
#
# studying leadership traditional critical approachesstudying leadership traditional critical approachesstudying leadership traditional critical approachesdorisschedlitzki garethedwards dorisschedlitzki garethedwards ba ba losangelessage
#
# strategic brand management building measuring and managing brand equity strategic brand management building measuring and managing brand equity strategic brand management building measuring and managing brand equity kevinlanekeller kevinlanekeller ba ba pearson
#
# intermediate accounting intermediate accounting intermediate accounting donalde.kieso jerryj.weygandt terryd.warfield donalde.kieso jerryj.weygandt terryd.warfield ba ba wiley
#
# biomedical signal and image processing dbiomedical signal and image processing dbiomedical signal and image processing dkayvannajarian robertsplinter kayvannajarian robertsplinter bme bme crcpress
#
# leadership communication leadership communication leadership communication deborahjbarrett deborahjbarrett ba ba mcgrawhill
#
# global leadership research practice and development global leadership research practice and development global leadership research practice and development markemendenhall markemendenhall ba ba wiley
#
# international human resource management international human resource management international human resource management allend.engle marionfesting peterj.dowling allend.engle marionfesting peterj.dowling ba ba cengagelearning
#
# leadershipeory and practice leadershipeory and practice leadershipeory and practice peterg.northouse peterg.northouse ba ba sage
#
# sustainable operations and supply chain managementsustainable operations and supply chain managementsustainable operations and supply chain managementalbertogrando valeriabelvedere albertogrando valeriabelvedere ise ise newjersey
#
# information technology for managers information technology for managers information technology for managers georgew.reynolds georgew.reynolds ba ba australia
#
# an introduction to derivatives and risk management an introduction to derivatives and risk management an introduction to derivatives and risk management donm.chance robertbrooks donm.chance robertbrooks ba ba australia
#
# ingenius a crash course on creativity ingenius a crash course on creativity ingenius a crash course on creativity tinaseelig tinaseelig ise ise newyork
#
# mathematical methods for engineers and scientists complex analysis determinants and matricesmathematical methods for engineers and scientists complex analysis determinants and matricesmathematical methods for engineers and scientists complex analysis determinants and matricesk.t.tang k.t.tang physi physi springer
#
# physics ofe space environmentphysics ofe space environmentphysics ofe space environmenttamasi.gombosi tamasi.gombosi physi physi newyork
#
# sparks of geniuseirteeninking tools ofe world s most creative peoplesparks of geniuseirteeninking tools ofe world s most creative peoplesparks of geniuseirteeninking tools ofe world s most creative peoplerobertscott root-bernstein robertscott root-bernstein ise ise boston
#
# e logistics managing your digital supply chains for competitive advantagee logistics managing your digital supply chains for competitive advantagee logistics managing your digital supply chains for competitive advantagestevepettit yingliwang stevepettit yingliwang ise ise london
#
# digital image processing digital image processing digital image processing rafaelc.gonzalez richarde.woods rafaelc.gonzalez richarde.woods physi physi newyork
#
# elementary differential equations and boundary value problemselementary differential equations and boundary value problemselementary differential equations and boundary value problemsdouglasb.meade richardc.diprima williame.boyce douglasb.meade richardc.diprima williame.boyce physi physi newjersey
#
# fundamentals of photonics fundamentals of photonics fundamentals of photonics b.e.a.saleh m.c.teich b.e.a.saleh m.c.teich physi physi newjersey
#
# q skills for success listening and speaking q skills for success listening and speaking q skills for success listening and speaking robertfreire tamarajones robertfreire tamarajones english english oxforduniversitypress
#
# q skills for success listening and speaking q skills for success listening and speaking q skills for success listening and speaking susanearlecarlin susanearlecarlin english english oxforduniversitypress
#
# accounting accounting accounting carls.warren jamesm.reeve jonathane.duchac carls.warren jamesm.reeve jonathane.duchac ba ba cengagelearning
#
# marketing channels a management view marketing channels a management view marketing channels a management view bertrosenbloom bertrosenbloom ba ba south-westerncengagelearning
#
# export importeory practice and procedures export importeory practice and procedures export importeory practice and procedures belayseyoum belayseyoum ise ise englandroutledge
#                              author faculty  id  isbn location  \
# 0      Project management Institute     ISE   1  None     None
# 1     Igor A. Karnovsky, Olga Lebed      CE   2  None     None
# 2                    Alan L. Harvey      BT   3  None     None
# 3                   Frank K. Reilly  BA, FN   4  None     None
# 4  John S. Lucas, Paul C. Southgate      BT   5  None     None
#
#                                                 name  \
# 0  A guide to the project management body of know...
# 1            Advanced Methods of Structural Analysis
# 2              Advances in Drug Discovery Techniques
# 3  Analysis of investment & management of portfol...
# 4  Aquaculture: Farming Aquatic Animals and Plant...
#
#                             publisher  year      type  \
# 0  Project Management Institute, Inc.  2008  database
# 1                            Springer  2010  database
# 2                   John Wiley & Sons  1998  database
# 3      South-Western Cengage Learning  2012  database
# 4                   John Wiley & Sons  2011  database
#
#                   author_clean faculty_clean                  publisher_clean  \
# 0   projectmanagementinstitute           ise  projectmanagementinstitute inc.
# 1    igora.karnovsky olgalebed            ce                         springer
# 2                 alanl.harvey            bt                   johnwiley&sons
# 3                frankk.reilly         ba fn     south-westerncengagelearning
# 4  johns.lucas paulc.southgate            bt                   johnwiley&sons
#
#                                         bag_of_words
# 0  a guide toe project management body of knowled...
# 1  advanced methods of structural analysisadvance...
# 2  advances in drug discovery techniquesadvances ...
# 3  analysis of investment management of portfolio...
# 4  aquaculture farming aquatic animals and plants...

# %%
# Convert word to vector and calculate similarity
# instantiating and generating the count matrix
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(book_list_df['bag_of_words'])
# generating the cosine similarity matrix base on cosine_sim
cosine_sim_matrix = cosine_similarity(count_matrix, count_matrix)
